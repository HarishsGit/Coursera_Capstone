# %% [markdown]
# ## Find the best neighborhood location in Toronto to open a Restaurant

# %% [markdown]
# ### Introduction

# %% [markdown]
# The purpose of this project is to help in finding a better place to establish new restaurant in Torono. There are many venues in each neighborhood and need to identify the best place for a resaurant. We'll be showing the location on map using Folium library and with the help of FourSquare API getting location information.

# %% [markdown]
# ### Problem Description

# %% [markdown]
# The primary purpose of this project is identifying the best location in Toronto. We'll take considet few things like high densly populated neighborhood, less number of restaurants based on that we suggest a best location.

# %% [markdown]
# ### Data Description

# %% [markdown]
# Link to Canada Postal Codes: https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M
#
# We will scape the data from the wiki page and use the postal code to link to the latitude and longitudes of Toronto.
#
# **FourSquare API:**
#
# The project will be totally based on the FourSquare API Location data, which it gives the relevant information needed to solve this problem. We can easily plot with latitude and longitude we pulled from the above wiki page and location file.
#
# **2016 canada population Census**
#
# https://www12.statcan.gc.ca/census-recensement/2016/dp-pd/hlt-fst/pd-pl/Tables/File.cfm?T=1201&SR=1&RPP=9999&PR=0&CMA=0&CSD=0&S=22&O=A&Lang=Eng&OFT=CSV
# With the above link we retrive the data and transfer into pandas dataframe.Then use the data to describe the highly populated neighborhoods.
#
# Samaple screenshot showing the data:
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Methodology

# %% [markdown]
# **K-Means Clustering Algorithm**
#
# The analysis we did is based on the K-Means clustering technique. This technique is help to identify the top 10 venues in each neighborhood. We then grouped and merged to orginal data frame and performed the analysis based on the data to identify the high dense cluster which is over best choice of location.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Results

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The location, University of Toronto, in Downtown Toronto is best location identified to establish a restaurant.

# %% [markdown]
# ### Discussion and Observations

# %% [markdown]
# As we do the analysis on the list of neighborhoods with top 10 listing of venues it gives us the clear picture of what type of restaurants is lacking in those neighborhood. So we can concentrate on those neighborhoods to start a new store or service in future. One of the observation is most of the neighborhoods doesn't have the saloon service so it would be ideal to start new one in those neighborhoods.

# %% [markdown]
# ### Conclusion

# %% [markdown]
# In this Capstone project, using K-Means clustering algorithm, we separated the neighborhoods based on clustes and identified the best location to establish a new restaurant.
